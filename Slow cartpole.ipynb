# %%
import gym
import time

env = gym.make('CartPole-v0')

# %%
env.reset()
env.render()
for action in [0, 1] * 25:
    obs, r, is_done, info = env.step(action)
    print(obs)
    env.render()
# Out:
# [ 0.02483896 -0.1887186   0.01735207  0.33055789]
# [0.02106459 0.00615211 0.02396323 0.04339709]
# [ 0.02118763 -0.18930513  0.02483117  0.34354328]
# [0.01740153 0.00545493 0.03170204 0.05879287]
# [ 0.01751063 -0.19010689  0.0328779   0.36130704]
# [0.01370849 0.00453268 0.04010404 0.07916983]
# [ 0.01379914 -0.19114054  0.04168743  0.38423109]
# [0.00997633 0.00336553 0.04937206 0.10497803]
# [ 0.01004364 -0.19242792  0.05147162  0.4128198 ]
# [0.00619508 0.00192807 0.05972801 0.1367979 ]
# [ 0.00623364 -0.19399626  0.06246397  0.44770994]
# [0.00235372 0.00018903 0.07141817 0.17535252]
# [ 0.0023575  -0.19587849  0.07492522  0.48968318]
# [-0.00156007 -0.00188908  0.08471888  0.22152286]
# [-0.00159785 -0.19811336  0.08914934  0.53968122]
# [-0.00556012 -0.00435026  0.09994296  0.27636597]
# [-0.00564712 -0.20074552  0.10547028  0.59882313]
# [-0.00966203 -0.00724506  0.11744675  0.34113613]
# [-0.00980694 -0.20382512  0.12426947  0.66842489]
# ...

# %%
env.close()

# %%
env.reset()
# Out:
# array([ 0.01185654, -0.00271653, -0.03178488,  0.01432604])
